# %%
import matplotlib.pyplot as plt

def midpoint_line(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1

    d = dy - dx/2

    x, y = x1, y1
    x_points = [x]
    y_points = [y]

    while x < x2:
        x += 1

        if d < 0:
            d = d + dy
        else:
            y += 1
            d = d + dy - dx

        x_points.append(x)
        y_points.append(y)

    return x_points, y_points


# Input
x1 = int(input("Enter x1: "))
y1 = int(input("Enter y1: "))
x2 = int(input("Enter x2: "))
y2 = int(input("Enter y2: "))

x, y = midpoint_line(x1, y1, x2, y2)

print("\nGenerated Points:")
for i in range(len(x)):
    print(f"({x[i]}, {y[i]})")

plt.plot(x, y, marker='o')
plt.title("Midpoint Line Drawing Algorithm")
plt.grid(True)
plt.show()
# Out:
# Enter x1:  20
# Enter y1:  10
# Enter x2:  30
# Enter y2:  18
# Generated Points:
# (20, 10)
# (21, 11)
# (22, 12)
# (23, 12)
# (24, 13)
# (25, 14)
# (26, 15)
# (27, 16)
# (28, 16)
# (29, 17)
# (30, 18)
